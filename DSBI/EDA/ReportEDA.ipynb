# %% [markdown]
# ## Mihir Hebalkar
# ### 22070122120
# ### EDA Report Flexi Credit Course TY CS B

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/RimjimRazdan/cars_price_prediction/refs/heads/master/car%20data.csv')

# %%
df
# Out:
#      Selling_Price  Present_Price  Kms_Driven
# 0             3.35           5.59       27000
# 1             4.75           9.54       43000
# 2             7.25           9.85        6900
# 3             2.85           4.15        5200
# 4             4.60           6.87       42450
# ..             ...            ...         ...
# 296           9.50          11.60       33988
# 297           4.00           5.90       60000
# 298           3.35          11.00       87934
# 299          11.50          12.50        9000
# 300           5.30           5.90        5464
#
# [301 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df=df.iloc[:,:-1]

# %%
pearson_corr = df.corr()
print("Correlation matrix ", pearson_corr)
# Out:
# Correlation matrix                 Selling_Price  Present_Price  Kms_Driven
# Selling_Price       1.000000       0.878983    0.029187
# Present_Price       0.878983       1.000000    0.203647
# Kms_Driven          0.029187       0.203647    1.000000

# %%
cov_matrix = df.cov()
print(cov_matrix)
# Out:
#                Selling_Price  Present_Price    Kms_Driven
# Selling_Price      25.834973      38.619337  5.768966e+03
# Present_Price      38.619337      74.720731  6.845447e+04
# Kms_Driven       5768.965732   68454.466283  1.512190e+09

# %%
cov_matrix = df.cov()
print("covarience ", cov_matrix)
# Out:
# covarience                 Selling_Price  Present_Price    Kms_Driven
# Selling_Price      25.834973      38.619337  5.768966e+03
# Present_Price      38.619337      74.720731  6.845447e+04
# Kms_Driven       5768.965732   68454.466283  1.512190e+09

# %%
data2 = {
    'Course' : ['CSE', 'ECE', 'MECH', 'CIVIL', 'Aren'],
    'Students': [120, 90, 70, 50, 100]
}
df2 = pd.DataFrame(data2)

df2
# Out:
#   Course  Students
# 0    CSE       120
# 1    ECE        90
# 2   MECH        70
# 3  CIVIL        50
# 4   Aren       100

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(8, 5))
sns.barplot(x = 'Course', y='Students', data = df2)
plt.title('Bar Chart')
plt.xlabel('Course')
plt.ylabel('Number of Students')
plt.show()

plt.figure(figsize=(8,8))
plt.pie(df2['Students'], labels=df2['Course'], autopct='%1.1f%%', startangle=90)
plt.title('Distribution of students across branches')
plt.axis('equal')
# Out:
# (np.float64(-1.099999150795326),
#  np.float64(1.0999997769359031),
#  np.float64(-1.099999708124928),
#  np.float64(1.099999986101187))

# %%
np.random.seed(42)
data = np.random.normal(loc=50, scale=15, size=200)

# Create a figure
plt.figure(figsize=(12, 10))

# Histogram
plt.subplot(2, 2, 1)
plt.hist(data, bins=20, color='skyblue', edgecolor='black')
plt.title("Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")

# Boxplot
plt.subplot(2, 2, 2)
sns.boxplot(x=data, color='lightcoral')
plt.title("Boxplot")

# Violinplot
plt.subplot(2, 2, 3)
sns.violinplot(x=data, color='lightgreen')
plt.title("Violin Plot")

# Histogram with KDE
plt.subplot(2, 2, 4)
sns.histplot(data, bins=20, kde=True, color='purple')
plt.title("Histogram with KDE")

# Adjust layout and show plots
plt.tight_layout()
plt.show()

# %% [markdown]
# # **EDA - Central Tendency, Range, and Plots**
#
# ### **1. Central Tendency**
#
# - **Mean** (Arithmetic Average):
#   - Sum of data points by number of observations.
#
# - **Median** (Middle Value of Sorted Data):
#   - If \(n\) is odd: Middle element of the sorted data.
#   - If \(n\) is even: Average of the two middle elements.
#
# - **Mode** (Most Frequent Value):
#   - The value that occurs most frequently in the dataset.
#
# ### **2. Range**
#
# - **Range** (Difference Between Max and Min Values):
#   \[
#     {Range} = max(x) - min(x)
#   \]
#   Where:
#   - \(max(x)\) = maximum value in the dataset
#   - \(min(x)\) = minimum value in the dataset
#
# ### **3. Plots**
#
# - **Histogram**:
#   - Visualizes the frequency distribution of a numerical variable.
#   - Helps identify skewness, peaks, and spread of data.
#
#   - Code Example (Python):
#     ```python
#     import matplotlib.pyplot as plt
#     plt.hist(data, bins=20)
#     plt.title('Histogram')
#     plt.xlabel('Value')
#     plt.ylabel('Frequency')
#     plt.show()
#     ```
#
# - **Box Plot**:
#   - Shows the spread of the data using quartiles (min, Q1, median, Q3, max).
#   - Identifies outliers (values outside 1.5 times the IQR from the quartiles).
#
#   - Code Example (Python):
#     ```python
#     import seaborn as sns
#     sns.boxplot(data=data)
#     plt.title('Box Plot')
#     plt.show()
#     ```
#
# - **KDE Plot** (Kernel Density Estimate):
#   - Smooths the data to estimate the probability density function of a continuous variable.
#
#   - Code Example (Python):
#     ```python
#     sns.kdeplot(data, shade=True)
#     plt.title('KDE Plot')
#     plt.show()
#     ```
#
# ### **4. Summary**
#
# - **Central Tendency**: Measures the "center" of the data (Mean, Median, Mode).
# - **Range**: Shows the spread of the data from the minimum to the maximum.
# - **Plots**: Visualize the distribution and patterns in the data (Histogram, Box Plot, KDE Plot).
